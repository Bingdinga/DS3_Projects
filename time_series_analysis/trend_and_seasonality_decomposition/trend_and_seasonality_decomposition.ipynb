# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.seasonal import STL
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data_files_trend_and_seasonality_decomposition/ILINet.csv', skiprows=1)

# %%
print(df.info())
print(df.isnull().sum())
print(df['REGION'].unique())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 625 entries, 0 to 624
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   REGION TYPE        625 non-null    object
#  1   REGION             625 non-null    object
#  2   YEAR               625 non-null    int64
#  3   WEEK               625 non-null    int64
#  4   % WEIGHTED ILI     625 non-null    float64
#  5   %UNWEIGHTED ILI    625 non-null    float64
#  6   AGE 0-4            625 non-null    int64
#  7   AGE 25-49          625 non-null    int64
#  8   AGE 25-64          625 non-null    object
#  9   AGE 5-24           625 non-null    int64
#  10  AGE 50-64          625 non-null    int64
#  11  AGE 65             625 non-null    int64
#  12  ILITOTAL           625 non-null    int64
#  13  NUM. OF PROVIDERS  625 non-null    int64
#  14  TOTAL PATIENTS     625 non-null    int64
# dtypes: float64(2), int64(10), object(3)
# memory usage: 73.4+ KB
# None
# REGION TYPE          0
# REGION               0
# YEAR                 0
# WEEK                 0
# % WEIGHTED ILI       0
# %UNWEIGHTED ILI      0
# AGE 0-4              0
# AGE 25-49            0
# AGE 25-64            0
# AGE 5-24             0
# AGE 50-64            0
# AGE 65               0
# ILITOTAL             0
# NUM. OF PROVIDERS    0
# TOTAL PATIENTS       0
# dtype: int64
# ['X']
#   REGION TYPE REGION  YEAR  WEEK  % WEIGHTED ILI  %UNWEIGHTED ILI  AGE 0-4  \
# 0    National      X  2013    40         1.15746          1.13249     2974
# 1    National      X  2013    41         1.27184          1.21121     3276
# 2    National      X  2013    42         1.31623          1.25682     3483
# 3    National      X  2013    43         1.37444          1.37097     3930
# 4    National      X  2013    44         1.46781          1.42956     4045
#
#    AGE 25-49 AGE 25-64  AGE 5-24  AGE 50-64  AGE 65  ILITOTAL  \
# 0       1840         X      3769        638     456      9677
# 1       1924         X      3925        762     533     10420
# 2       2010         X      3880        785     500     10658
# 3       2292         X      4484        816     514     12036
# 4       2354         X      4642        930     531     12502
#
#    NUM. OF PROVIDERS  TOTAL PATIENTS
# 0               1960          854487
# 1               1990          860298
# 2               2018          848016
# 3               2027          877917
# 4               2028          874537
